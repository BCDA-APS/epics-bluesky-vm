# %% [markdown]
# # Databroker example: area detector image
#
# *APS Training for Bluesky Data Acquisition*.
#
# **Objective**
#
# Using data stored by the databroker from previous runs, find position and size of a blob (simulated diffraction peak) in a 2-D area detector image.
#
# ## Preparation
#
# Import the libraries needed for this example.  Note that the `bluesky`, `ophyd`, and `epics` (PyEpics) packages are not needed.

# %%
import databroker
from scipy import ndimage
from apstools.utils import listruns

cat = databroker.catalog["class_example_data"]
print(f"{len(cat) = }")
# Out:
# len(cat) = 41

# %% [markdown]
# Print a list of the runs in this databroker catalog of example data.  The default is to show 20 runs.  Change that to show all (by giving a number that is obviously more than the example data holds).

# %%
listruns(db=cat.v1, num=100)
# Out:
# catalog: training
#     scan_id                 time plan_name      detectors
# 0        25  2021-04-11 09:08:00  rel_scan        [noisy]
# 1        24  2021-04-11 09:07:53  rel_scan        [noisy]
# 2        23  2021-04-11 09:07:44  rel_scan        [noisy]
# 3        22  2021-04-11 09:07:26  rel_scan        [noisy]
# 4        21  2021-04-11 09:07:17  rel_scan        [noisy]
# 5        20  2021-04-11 09:07:02  rel_scan        [noisy]
# 6        19  2021-04-11 09:05:36     count     [adsimdet]
# 7        18  2021-04-11 09:04:37     count  [temperature]
# 8        17  2021-04-11 09:04:16     count  [temperature]
# 9        16  2021-04-11 09:04:15     count  [temperature]
# 10       15  2021-04-11 09:04:14     count  [temperature]
# 11        4  2021-04-11 08:56:33      scan        [vsc16]
# 12        3  2021-04-11 08:55:28      scan        [vsc16]
# 13        2  2021-04-11 08:52:07      scan        [vsc16]
# 14        1  2021-04-11 08:51:11      scan        [vsc16]
# 15       14  2021-04-10 21:37:49  rel_scan        [noisy]
# 16       13  2021-04-10 21:37:48     count     [adsimdet]
# 17       13  2021-04-10 21:37:34  rel_scan        [noisy]
# 18       12  2021-04-10 21:37:21  rel_scan        [noisy]
# 19       11  2021-04-10 21:37:03  rel_scan        [noisy]
# 20       10  2021-04-10 21:36:54  rel_scan        [noisy]
# 21        9  2021-04-10 21:36:37  rel_scan        [noisy]
# 22        8  2021-04-10 21:34:57     count     [adsimdet]
# 23        7  2021-04-10 21:33:22     count  [temperature]
# 24        6  2021-04-10 21:32:44     count  [temperature]
# 25        5  2021-04-10 21:32:34     count  [temperature]
# 26        4  2021-04-10 21:32:26     count  [temperature]
# 27        7  2021-04-10 12:17:38      scan        [vsc16]
# 28        6  2021-04-10 12:17:27      scan        [vsc16]
# 29        5  2021-04-10 12:17:16      scan        [vsc16]
# 30        4  2021-04-10 12:16:50      scan        [vsc16]
# 31        3  2021-04-10 12:05:58      scan        [vsc16]
# 32        2  2021-04-10 11:53:49      scan        [vsc16]
# 33        1  2021-04-10 11:48:30      scan        [vsc16]
# 34        2  2021-04-08 21:20:22      scan      [joerger]
# 35        1  2021-04-08 21:19:47      scan      [joerger]
# 36        2  2021-04-08 21:12:26      scan      [joerger]
# 37        1  2021-04-08 21:11:09      scan      [joerger]
# 38        3  2021-04-08 20:43:15  rel_scan        [noisy]
# 39        2  2021-04-08 20:41:39  rel_scan        [noisy]
# 40        1  2021-04-08 20:40:15  rel_scan        [noisy]

# %% [markdown]
# The list is not sorted by date (which is a [bug in the listruns code](https://github.com/BCDA-APS/apstools/issues/498) now.)
#
# ## Select the run
# Get the run with `scan_id=82` from the databroker catalog of example data.

# %%
run = cat.search({"scan_id": 82})[-1]
run
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Apps/miniconda3/envs/bluesky_2021_1/lib/python3.8/site-packages/databroker/_drivers/mongo_normalized.py in _find_run_start_doc(self, name)
#     120                 try:
# --> 121                     run_start_doc, = cursor
#     122                 except ValueError:
#
# ValueError: not enough values to unpack (expected 1, got 0)
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-73f6728d9801> in <module>
# ----> 1 run = cat.search({"scan_id": 82})[-1]
#       2 run
#
# ~/Apps/miniconda3/envs/bluesky_2021_1/lib/python3.8/site-packages/intake/catalog/base.py in __getitem__(self, key)
#     385         cat['name1', 'name2']
#     386         """
# --> 387         if not isinstance(key, list) and key in self._get_entries():
#     388             # triggers reload_on_change
#     389             e = self._entries[key]
#
# ~/Apps/miniconda3/envs/bluesky_2021_1/lib/python3.8/site-packages/databroker/_drivers/mongo_normalized.py in __contains__(self, key)
#     146         # if we *can* create such an Entry.
#     147         try:
# --> 148             self._find_run_start_doc(key)
#     149         except KeyError:
#     150             return False
#
# ~/Apps/miniconda3/envs/bluesky_2021_1/lib/python3.8/site-packages/databroker/_drivers/mongo_normalized.py in _find_run_start_doc(self, name)
#     121                     run_start_doc, = cursor
#     122                 except ValueError:
# --> 123                     raise IndexError(
#     124                         f"Catalog only contains {len(self.catalog)} "
#     125                         f"runs.")
#
# IndexError: Catalog only contains 0 runs.

# %% [markdown]
# ## Get datasets
# Get the datasets from the *primary* stream.

# %%
ds = run.primary.read()
ds

# %% [markdown]
# ## Get image frame data
# The data to examine is `adsimdet_image`.  It's the only one.  We have to dereference two indices for how the frame was packed by EPICS area detector into the HDF5 file.  Also, the *scipy* package wants to receive a numpy `ndarray` so we must convert from the `xarray.Dataset`.

# %%
frame = ds["adsimdet_image"][0][0]
np_frame = frame.to_masked_array().data
np_frame

# %% [markdown]
# #3 Analysis
# Print some basic measures of this image frame.

# %%
print(f"{ndimage.measurements.center_of_mass(np_frame)   = }")
print(f"{ndimage.measurements.maximum_position(np_frame) = }")
print(f"{np_frame.max() = }")
print(f"{np_frame.min() = }")

# %% [markdown]
# ## Visualize
# Show the frame as an image.The `xarray.Dataset` has a plot method.

# %%
frame.plot.pcolormesh()
